# %%
import pandas as pd
from miniArkivet import miniArkivet
df = miniArkivet("tests")
print(df.describe())
df
# Out:
#                                title bildtext        date  \
# count                             28       28          28
# unique                            12        3          12
# top     Rapport från en kylskåpsdörr           2004-11-26
# freq                               4       24           6
#
#                   published                    url        newspaper page  \
# count                    28                     28               28   28
# unique                    2                     14                1    6
# top     Publicerat på webb.  http://ret.nu/7Ml1g0k  Hagens Knuheter
# freq                     16                      2               28   16
#
#            copyright                                               text
# count             28                                                 28
# unique             1                                                 13
# top     ©Sonnier<br>  Magna, pvis finibus tempus libero non mollis. ...
# ...

# %% [markdown]
# ## Manipulate the dataframe

# %%
df['alltext'] = df[['title', 'bildtext','text']].apply('\n'.join, axis=1)

df['titlelength']= df['title'].apply(len)
df['alltextlength'] = df['alltext'].apply(len)
print(df)
# Out:
#                                                 title  \
# 0                                     Tro och vetande
# 1   Globaliseringen nytt fokus för utrikesinstitut...
# 2      Globaliseringen nytt fokus för utrikesinstitut
# 3   Reinfeldt vinner väljare från alla övriga part...
# 4   Reinfeldt vinner väljare från alla övriga partier
# 5                Jusjtjenko anses ha vunnit tv-debatt
# 6       Schwarzenegger stärkt av första guvernörsåret
# 7                Kineserna får gärna ta över Norrmalm
# 8                        Rapport från en kylskåpsdörr
# 9                        Rapport från en kylskåpsdörr
# 10     Nu höjs röster över hela landet mot mansvåldet
# 11                 Från pitemännens nätverk i norr...
# 12                       De onda, de goda och de fula
# 13                       De onda, de goda och de fula
# 14                                    Tro och vetande
# 15  Globaliseringen nytt fokus för utrikesinstitut...
# ...

# %% [markdown]
# # Save and load

# %%
# !pip install openpyxl
df.to_excel("excel.xlsx", sheet_name='markivetdata')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 24.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
df.to_csv('all.csv', index=False)

# %%
dfnew = pd.read_csv('all.csv', index_col=0)
dfnew.describe(include='all')
# Out:
#                              bildtext        date            published  \
# count                               4          28                   28
# unique                              2          12                    2
# top     Bildtext: FOTO: JESSICA GOW\n  2004-11-26  Publicerat på webb.
# freq                                2           6                   16
# mean                              NaN         NaN                  NaN
# std                               NaN         NaN                  NaN
# min                               NaN         NaN                  NaN
# 25%                               NaN         NaN                  NaN
# 50%                               NaN         NaN                  NaN
# 75%                               NaN         NaN                  NaN
# max                               NaN         NaN                  NaN
#
#                           url        newspaper    page     copyright  \
# ...

# %%
df_dummy = miniArkivet("dummy")
print(df_dummy.describe())
df_dummy
# Out:
#           page
# count  15000.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
#                                                    title  \
# 0      How to get all the child records from differen...
# 1      Retrieve all except some data of the another t...
# 2                                      Pandas: read_html
# 3                               Reader Always gimme NULL
# 4        php rearrange array elements based on condition
# ...                                                  ...
# 14995  How can I align two flex boxes to follow each ...
# 14996  C++ The correct way to multiply an integer and...
# 14997  WHY DJANGO IS SHOWING ME THIS ERROR WHEN I TRY...
# 14998              PHP - getting the content of php page
# 14999  Why can't overloaded functions vary only by re...
#
#                                                     text        date  \
# ...
